# %% [markdown]
# # Sophearath Chea COMP 4447 HW 1

# %% [markdown]
# ### Question 1: Why we need Python virtual environments?
# A virtual environment is a tool that helps to keep dependencies required by different projects separate by creating isolated python virtual environments for them. We need Python virtual environments to maintain dependencies on different projects, that for example might required different versions of modules or packages, in order to run.

# %%
### Question 2: Sort following list in place alphabetically using last three character.
continentsL = ['Europe', 'Africa', 'America', 'Antarctica', 'Asia', 'Australia']
def MyFn(s): return s[-3:]
print(sorted(continentsL, key=MyFn))
# Out:
# ['Africa', 'America', 'Antarctica', 'Australia', 'Europe', 'Asia']

# %% [markdown]
# ### Question 3:
# We want to compare random integer generation time in numpy and random module of python. Generate 100 random integer in the range 1 to 10 including 1 and 10.
# Write jupyter notebook line magic to compare execution time of random integer generation in the following cells(look for the cells having the comment write line magic).
# Line magic must execute the given statement 10 times in a loop and repeats 5 times.

# %%
# Code to generate random integers in Python.
import random
num_sample = 100
low = 1
high = 10

# %%
# write line magic for random module in the next line
# %timeit -n 10 -r 5 for x in range(num_sample):random.randint(low,high)
# Out:
# 108 µs ± 6.39 µs per loop (mean ± std. dev. of 5 runs, 10 loops each)

# %%
# Code to generate random integers in Numpy.
import numpy as np

# %%
# write line magic for numpy randint in the next line
# %timeit -n 10 -r 5 np.random.randint(low,11, size=num_sample)
# Out:
# The slowest run took 22.74 times longer than the fastest. This could mean that an intermediate result is being cached.
# 16.1 µs ± 24.8 µs per loop (mean ± std. dev. of 5 runs, 10 loops each)

# %% [markdown]
# ### Question 4:
# List your team members in bullet format.(No more than 3 members. It'll be hard for us to allow changing team member at a later stage.)
# Answer: Undetermined

# %% [markdown]
# ### Question 5:  What problem you are trying to solve?
# Problem from: https://makingnoiseandhearingthings.com/2018/04/19/datasets-for-data-cleaning-practice/.
#
# #### National Drug Code Directory
# The Drug Listing Act of 1972 requires registered drug establishments to provide the Food and Drug Administration (FDA) with a current list of all drugs manufactured, prepared, propagated, compounded, or processed by it for commercial distribution. Drug products are identified and reported using a unique, three-segment number, called the National Drug Code (NDC), which serves as a universal product identifier for drugs. FDA publishes the listed NDC numbers and the information submitted as part of the listing information in the NDC Directory which is updated daily.The information submitted as part of the listing process, the NDC number, and the NDC Directory are used in the implementation and enforcement of the Act.
#
# Problem: Non-trivial duplication. Which drugs are different names for the same things?

# %% [markdown]
# ### Question 6:Describe the attributes of examples in the dataset
# See image below. I will describe the attributes (columns) of the product in row 2.
# 1. The Product ID (column A) is '43353-010_8ade0dd7-67ee-45f4-9713-95d3991a5bd9.'
#     - ProductID is a concatenation of the NDCproduct code and SPL documentID. It is included to help prevent duplicate rows from appearing when joining the product and package files together.  It has no regulatory value or significance.
# 1. The ProductNDC (column B) is '43353-010.'
#     - The labeler code and product code segments of the National Drug Code number.
# 1. The ProductTypeName (column C) is 'HUMAN PRESCRIPTION DRUG.'
#     - Indicates the type of product, such as Human Prescription Drug or Human OTC Drug.
# 1. The ProprietaryName (column D) is 'Acetaminophen and Codeine.'
#     - Also known as the trade name. It is the name of the product chosen by the labeler.
# 1. The NonProprietaryName (column F) is 'Acetaminophen and Codeine.'
#     - Sometimes called the generic name, this is usually the active ingredient(s) of the product.
# 1. The DosageFormName (column G) is 'TABLET.'
#     - The translation of the DosageForm Code submitted by the firm.
# 1. The RouteName (column H) is 'ORAL.'
#     - The translation of the Route Code submitted by the firm, indicating route of administration.
# 1. The StartMarketingDate (column I) is '20080529'
#     - This is the date that the labeler indicates was the start of its marketing of the drug product.
# 1. The MarketingCategoryName (column k) is 'ANDA.'
#     - Product types are broken down into several potential Marketing Categories, such as NDA/ANDA/BLA, OTC Monograph, or Unapproved Drug
# 1. The ApplicationNumber (column L) is 'ANDA040779.'
#     - This corresponds to the NDA, ANDA, or BLA number reported by the labeler for products.
# 1. The LabelerName is (column M) 'Aphena Pharma Solutions - Tennessee, LLC.'
#     - Name of Company.
# 1. The SubstanceName is (column N)'ACETAMINOPHEN; CODEINE PHOSPHATE.'
#     - This is the active ingredient list.
# 1. The StrengthNumber (column O) is '300; 30.'
#     - This is the strength values of each active ingredient, listed in the same order as the SubstanceName.
# 1. The StrengthUnit (column P) is 'mg/1; mg/1'
#     - These are the units to be used with the strength values, listed in the same order as the SubstanceName and SubstanceNumber.
# 1. The Pharm_Classes (column Q) is 'Full Opioid Agonists [MoA],Opioid Agonist [EPC]'
#     - These are the reported pharmacological class categories corresponding to the SubstanceNames listed above.
# 1. The DEASchedule (column R) is 'CIII.'
#     - This is the assigned DEA Schedule number as reported by the labeler. Values are CI, CII, CIII, CIV, and CV.
# 1. The Listing_Record_Certified_Through (column T) is '20191231.'
#     - An indicator that equals 'E' when the product has been removed/excluded from the NDC Directory for failure to respond to FDA’s requests for correction to deficient or non-compliant submissions
#
# Full descriptions of variables in the data set is avaliable here: https://www.fda.gov/Drugs/InformationOnDrugs/ucm254527.htm

# %% [markdown]
# ### Question 7: Give example of records(sample points). Why this is a noisy data set (highlight portion of record attributes you think are noisy).
# An image of 7 sample rows from the NDC Dataset is show below. All 7 of these rows are for the drug named 'Acetaminphen and Codeine.'
#
# I have highlighted the portions of the sample record attributes I think are noisy.
# 1. The 'SUBSTANCENAME' column (column N) is the active ingredient list. The 'ACTIVE_NUMERATOR_STRENGTH' column (column O) are the strength values of each active ingredient, listed in the same order as the SubstanceName. As you can see in rows 4 and 6, the active ingredients are listed in a different order then in rows 1,2,5,7 and 8 and as a reulst the strength values in column O are also out of order. This could be a problem if you want to find all the rows of a particular drug. It also makes it harder to compare the strength of the active ingredients.
#
# 1. Column S is an indicator that equals 'E' when the product has been removed/excluded from the NDC Directory for failure to respond to FDA’s requests for correction to deficient or non-compliant submissions. Column R to the left of column S, shows the assigned DEA Schedule number and has values: 'CI', 'CII', 'CIII', 'CIV', and 'CV'. As you can see in row 6, the DEA Schedule number for this drug is missing. This information is missing for all products with a value of 'E' in Column S. From looking at the other rows in this sample, which are all also for 'Acetaminphen and Codeine,' we can conclude that this missing value should be 'CIII.' Again, however given that this list is not sorted by active ingredients, which are sometimes listed in different orders, in some cases it may be hard to determine what the missing value for DEA Schedule number should be.
#
# 1. Last small concern: Through out the data there is inconsistant capitalization (see rows 6 and 7).

# %%
#Code to display image of the sample points from NDC Dataset
from PIL import Image
from IPython.display import display
pil_im = Image.open('Desktop/picture.png')
display(pil_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3472x240 at 0x1185C1128>

# %% [markdown]
# ### Question 8: What kind of feature engineering opportunity you see.
# Example Given is HW: Do you need to extract a number, year, or a word in column(attribute of a record).
#
# As I discussed in question 7, it might be useful to extract the name of the highest strength active ingredient from the SubstanceName column (based on the strength values given in column O and the units of these strength values in column P), so that we can better compare and group drug products that are chemically identical or very similar.
